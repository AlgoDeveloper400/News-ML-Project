# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime
from collections import defaultdict
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import autocast, GradScaler
from sklearn.metrics import r2_score, mean_squared_error

# === Device ===
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# === Config ===
input_path = r"your file path\USD,ZAR AND EUR 2025 DATA.csv"
seq_length = 5
hidden_size = 64
num_layers = 2
dropout_rate = 0.2
batch_size = 64
epochs = 30
learning_rate = 0.001
weight_decay = 1e-4

# === Load Data ===
df = pd.read_csv(input_path, parse_dates=['DateTime'])
df = df.dropna(subset=['Actual', 'Previous', 'Currency', 'Event', 'Impact'])

df['EventMonth'] = df['DateTime'].dt.to_period('M')
df['EventDate'] = df['DateTime'].dt.date
current_month = pd.Timestamp.now().to_period('M')

# Count high-impact events per day
high_impact_counts = (
    df[df['Impact'] == 3]
    .groupby(['Currency', 'EventDate'])
    .size()
    .rename("HighImpactCount")
    .reset_index()
)
df = pd.merge(df, high_impact_counts, how='left', on=['Currency', 'EventDate'])
df['HighImpactCount'] = df['HighImpactCount'].fillna(0)

# Lag features
df = df.sort_values(['Currency', 'Event', 'DateTime'])
df['Actual_lag1'] = df.groupby(['Currency', 'Event'])['Actual'].shift(1)
df['Previous_lag1'] = df.groupby(['Currency', 'Event'])['Previous'].shift(1)
df['Actual_lag1'] = df['Actual_lag1'].fillna(method='bfill').fillna(method='ffill')
df['Previous_lag1'] = df['Previous_lag1'].fillna(method='bfill').fillna(method='ffill')

grouped = df.groupby(['Currency', 'Event'])

all_train_samples = []
all_test_samples = []
event_norm_params = {}
latest_month_data = {}

print("\n=== Preparing sequences per event ===")

def normalize_feature(arr):
    mn = arr.min()
    mx = arr.max()
    rng = mx - mn if mx != mn else 1
    return (arr - mn) / rng, mn, rng

for key, group in grouped:
    group = group.sort_values('DateTime')
    if len(group) < seq_length + 1:
        continue

    actuals = group['Actual'].values
    previous = group['Previous'].values
    impacts = group['Impact'].astype(float).values
    hicount = group['HighImpactCount'].astype(float).values
    actual_lag1 = group['Actual_lag1'].values
    prev_lag1 = group['Previous_lag1'].values
    months = group['EventMonth'].values

    norm_actuals, min_act, range_act = normalize_feature(actuals)
    norm_previous, min_prev, range_prev = normalize_feature(previous)
    norm_impacts, min_imp, range_imp = normalize_feature(impacts)
    norm_hic, min_hic, range_hic = normalize_feature(hicount)
    norm_al1, min_al1, range_al1 = normalize_feature(actual_lag1)
    norm_pl1, min_pl1, range_pl1 = normalize_feature(prev_lag1)

    event_norm_params[key] = {
        'actual': (min_act, range_act),
        'previous': (min_prev, range_prev),
        'impact': (min_imp, range_imp),
        'high_impact_count': (min_hic, range_hic),
        'actual_lag1': (min_al1, range_al1),
        'previous_lag1': (min_pl1, range_pl1),
    }

    features = np.stack([
        norm_actuals, norm_previous, norm_impacts,
        norm_hic, norm_al1, norm_pl1
    ], axis=1)

    targets = norm_actuals
    split_idx = int(len(features) * 0.7)

    for i in range(split_idx - seq_length):
        x = features[i:i+seq_length]
        y = targets[i+seq_length]
        all_train_samples.append((x, y, key))

    for i in range(split_idx, len(features) - seq_length):
        x = features[i:i+seq_length]
        y = targets[i+seq_length]
        all_test_samples.append((x, y, key))

    latest_month_data[key] = {
        'seq': features[-seq_length:],
        'has_current_month': current_month in months
    }

print(f"Total train samples: {len(all_train_samples)}")
print(f"Total test samples:  {len(all_test_samples)}")

# === Dataset + DataLoader ===
class EventDataset(Dataset):
    def __init__(self, samples):
        self.samples = samples

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        x, y, key = self.samples[idx]
        return torch.tensor(x, dtype=torch.float32), torch.tensor(y, dtype=torch.float32), key

def custom_collate_fn(batch):
    xs, ys, keys = zip(*batch)
    return torch.stack(xs), torch.tensor(ys), list(keys)

train_dl = DataLoader(EventDataset(all_train_samples), batch_size=batch_size, shuffle=True, collate_fn=custom_collate_fn)
test_dl = DataLoader(EventDataset(all_test_samples), batch_size=batch_size, shuffle=False, collate_fn=custom_collate_fn)

# === Model ===
class RNNModel(nn.Module):
    def __init__(self, input_size=6, hidden_size=64, num_layers=2, dropout=0.2):
        super().__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, dropout=dropout, batch_first=True)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.dropout(out[:, -1])
        return self.fc(out)

model = RNNModel().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
loss_fn = nn.MSELoss()
scaler = GradScaler()

# === Training ===
print("\n=== Training Starts ===")
model.train()
for epoch in range(epochs):
    total_loss = 0
    for xb, yb, _ in train_dl:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        with autocast():
            pred = model(xb).squeeze()
            loss = loss_fn(pred, yb)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        total_loss += loss.item()
    print(f"Epoch {epoch+1:02}/{epochs} - Loss: {total_loss / len(train_dl):.6f}")

# === Evaluation ===
print("\n=== Evaluation Per Event ===")
model.eval()
predictions = defaultdict(list)
actuals = defaultdict(list)

with torch.no_grad():
    for xb, yb, keys in test_dl:
        xb, yb = xb.to(device), yb.to(device)
        with autocast():
            preds = model(xb).squeeze()
        preds = preds.cpu().numpy()
        yb = yb.cpu().numpy()
        for i, key in enumerate(keys):
            predictions[key].append(preds[i])
            actuals[key].append(yb[i])

# === Metrics ===
event_stats = []
print(f"\n{'Currency':<10} | {'Event':<35} | {'R²':>6} | {'MSE':>10} | {'Samples':>8}")
print("-" * 80)

for key in sorted(predictions.keys()):
    if key not in event_norm_params:
        continue

    preds = predictions[key]
    trues = actuals[key]
    n = len(preds)

    if n < 5:
        continue

    min_act, range_act = event_norm_params[key]['actual']
    denorm_preds = [p * range_act + min_act for p in preds]
    denorm_trues = [a * range_act + min_act for a in trues]

    r2 = r2_score(denorm_trues, denorm_preds)
    mse = mean_squared_error(denorm_trues, denorm_preds)

    event_stats.append((key[0], key[1], r2, mse, n))
    print(f"{key[0]:<10} | {key[1][:35]:<35} | {r2:6.4f} | {mse:10.4f} | {n:8d}")

# === Save Output ===
output_dir = os.path.dirname(input_path)
summary_path = os.path.join(output_dir, "event_rnn_evaluation_summary.csv")
forecast_path = os.path.join(output_dir, "event_rnn_month_forecasts.csv")
model_path = os.path.join(output_dir, "event_rnn_model.pth")

summary_df = pd.DataFrame(event_stats, columns=["Currency", "Event", "R2", "MSE", "Samples"])
summary_df.to_csv(summary_path, index=False)
print(f"\n✅ Accuracy summary saved to: {summary_path}")

# === Forecast ===
print("\n=== Forecast for This/Next Month ===")
forecast_rows = []

for key, data in latest_month_data.items():
    seq = data['seq']
    month_target = "THIS" if not data['has_current_month'] else "NEXT"
    input_tensor = torch.tensor(seq, dtype=torch.float32).unsqueeze(0).to(device)
    with torch.no_grad(), autocast():
        pred = model(input_tensor).item()
    min_act, range_act = event_norm_params[key]['actual']
    denorm_pred = pred * range_act + min_act
    forecast_rows.append([key[0], key[1], month_target, denorm_pred])
    print(f"{key[0]} - {key[1][:35]:<35}: 🔮 Forecast for {month_target} month = {denorm_pred:.2f}")

forecast_df = pd.DataFrame(forecast_rows, columns=["Currency", "Event", "ForecastMonth", "ForecastValue"])
forecast_df.to_csv(forecast_path, index=False)
print(f"✅ Forecasts saved to: {forecast_path}")

# === Save Model ===
torch.save(model.state_dict(), model_path)
print(f"✅ Model weights saved to: {model_path}")
# Out:
# Using device: cpu
# C:\Users\Nokul\AppData\Local\Temp\ipykernel_3032\3303005374.py:50: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Actual_lag1'] = df['Actual_lag1'].fillna(method='bfill').fillna(method='ffill')
# C:\Users\Nokul\AppData\Local\Temp\ipykernel_3032\3303005374.py:51: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Previous_lag1'] = df['Previous_lag1'].fillna(method='bfill').fillna(method='ffill')
# === Preparing sequences per event ===
# Total train samples: 52553
# Total test samples:  21779
# C:\Users\Nokul\AppData\Local\Temp\ipykernel_3032\3303005374.py:158: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# C:\Users\Nokul\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\amp\grad_scaler.py:132: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
# C:\Users\Nokul\AppData\Local\Temp\ipykernel_3032\3303005374.py:168: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# C:\Users\Nokul\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# === Training Starts ===
# Epoch 01/30 - Loss: 0.017635
# Epoch 02/30 - Loss: 0.012518
# Epoch 03/30 - Loss: 0.011722
# Epoch 04/30 - Loss: 0.011274
# Epoch 05/30 - Loss: 0.011076
# Epoch 06/30 - Loss: 0.010879
# Epoch 07/30 - Loss: 0.010867
# Epoch 08/30 - Loss: 0.010725
# Epoch 09/30 - Loss: 0.010689
# Epoch 10/30 - Loss: 0.010706
# Epoch 11/30 - Loss: 0.010665
# Epoch 12/30 - Loss: 0.010604
# Epoch 13/30 - Loss: 0.010617
# Epoch 14/30 - Loss: 0.010588
# Epoch 15/30 - Loss: 0.010692
# Epoch 16/30 - Loss: 0.010574
# Epoch 17/30 - Loss: 0.010550
# Epoch 18/30 - Loss: 0.010526
# Epoch 19/30 - Loss: 0.010534
# Epoch 20/30 - Loss: 0.010521
# Epoch 21/30 - Loss: 0.010526
# Epoch 22/30 - Loss: 0.010508
# Epoch 23/30 - Loss: 0.010544
# Epoch 24/30 - Loss: 0.010549
# Epoch 25/30 - Loss: 0.010549
# Epoch 26/30 - Loss: 0.010535
# Epoch 27/30 - Loss: 0.010548
# Epoch 28/30 - Loss: 0.010473
# Epoch 29/30 - Loss: 0.010539
# Epoch 30/30 - Loss: 0.010566
#
# === Evaluation Per Event ===
# C:\Users\Nokul\AppData\Local\Temp\ipykernel_3032\3303005374.py:186: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# Currency   | Event                               |     R² |        MSE |  Samples
# --------------------------------------------------------------------------------
# EUR        | 10-Year BTP Auction                 | 0.3845 | 285517240278.0360 |       37
# EUR        | 10-Year Bond Auction                | -0.4041 | 65963759566.2693 |       48
# EUR        | 10-Year OAT Auction                 | 0.2031 | 177714576507.7480 |       36
# EUR        | 10-Year Obligacion Auction          | 0.8881 | 173541369617.8269 |       45
# EUR        | 12-Month BOT Auction                | 0.7340 | 289986109284.6966 |       39
# EUR        | 12-Month BTF Auction                | 0.9647 | 54786952329.6801 |      171
# EUR        | 12-Month Letras Auction             | 0.7145 | 262891050560.3381 |       38
# EUR        | 15-Year Obligacion Auction          | -26.8796 | 1346191677612.7664 |        8
# EUR        | 2-Year CTZ Auction                  | -0.3286 | 435241070072.0900 |       21
# EUR        | 2-Year Note Auction                 | 0.0759 | 169175615601.7234 |       40
# EUR        | 3-Month BTF Auction                 | 0.9790 | 50280326495.9079 |      173
# EUR        | 3-Month Letras Auction              | 0.8182 | 262649451025.2138 |       38
# EUR        | 3-Year BTP Auction                  | -0.3059 | 336941794650.1072 |       33
# EUR        | 3-Year Bonos Auction                | 0.6444 | 241637620075.8909 |       36
# EUR        | 3-Year OAT Auction                  | -0.4028 | 111267958109.4757 |       26
# EUR        | 30-Year BTP Auction                 | -0.3765 | 210634798915.8593 |        6
# EUR        | 30-Year Bond Auction                | -0.1774 | 57690434530.5818 |       30
# EUR        | 30-Year Obligacion Auction          | -2.9207 | 262507960410.8071 |        7
# EUR        | 5-Year BTP Auction                  | 0.6666 | 298051388912.1865 |       37
# EUR        | 5-Year Bonos Auction                | 0.8842 | 251985191769.5423 |       42
# EUR        | 5-Year Note Auction                 | 0.0209 | 59510546557.7820 |       38
# EUR        | 5-Year OAT Auction                  | -0.1210 | 203131489885.1743 |       32
# EUR        | 6-Month BOT Auction                 | 0.8114 | 334741650505.7931 |       36
# EUR        | 6-Month BTF Auction                 | 0.9762 | 50971115786.7743 |      173
# EUR        | 6-Month Letras Auction              | 0.7897 | 268249360194.2594 |       38
# EUR        | 7-Year BTP Auction                  | 0.4382 | 76555486499.6436 |       28
# EUR        | 9-Month Letras Auction              | 0.6378 | 258472282359.4953 |       36
# EUR        | Business Climate                    | 0.7069 | 4687773914852.4170 |       40
# EUR        | Business Climate Indicator          | 0.9285 | 33566662016.7678 |       37
# EUR        | Business Confidence                 | 0.0109 | 2430009545178056.0000 |       65
# EUR        | CFTC EUR Non-Commercial Net Positio | 0.8636 | 594569054615999.3750 |      226
# EUR        | CPI                                 | 0.1890 | 1746233419549.4585 |       38
# EUR        | CPI FOI excl. Tobacco m/m           | -0.0153 | 380476678997.0616 |       41
# EUR        | CPI FOI excl. Tobacco y/y           | 0.8344 | 2120890950275.5667 |       41
# EUR        | CPI excl. Energy and Unprocessed Fo | 0.0173 | 192585198298.4488 |       44
# EUR        | CPI excl. Energy and Unprocessed Fo | 0.9757 | 67230912178.1660 |       53
# EUR        | CPI excl. Tobacco m/m               | -0.1229 | 245408763123.6619 |       34
# EUR        | CPI excl. Tobacco y/y               | 0.9097 | 802155996488.8309 |       34
# EUR        | CPI m/m                             | 0.2204 | 255047699958.1876 |      425
# EUR        | CPI y/y                             | 0.7178 | 2309728899762.5781 |      416
# EUR        | Construction Output m/m             | -0.5527 | 3318194644729.5352 |       48
# EUR        | Construction Output y/y             | -0.0377 | 49526974854140.2891 |       49
# EUR        | Consumer Confidence                 | 0.0557 | 176541321405983.9688 |       64
# EUR        | Consumer Confidence Index           | 0.0916 | 2268190182009552.0000 |      139
# EUR        | Consumer Price Expectations         | 0.7679 | 24878316804117.3438 |       36
# EUR        | Consumer Spending m/m               | -1.6190 | 7942918089750.8818 |       48
# EUR        | Core CPI                            | 0.4201 | 1498021960332.8748 |       36
# EUR        | Core CPI m/m                        | -0.0732 | 304470875289.0767 |       50
# EUR        | Core CPI y/y                        | 0.9106 | 123321604240.6303 |       91
# EUR        | Current Account                     | 0.1486 | 175858025869250.0312 |      137
# EUR        | Current Account n.s.a.              | 0.2893 | 172153076863173.0938 |       83
# EUR        | ECB Deposit Facility Rate Decision  | 0.2224 | 628056235831.2531 |       23
# EUR        | ECB Households Loans y/y            | 0.9292 | 186563921277.9055 |       38
# EUR        | ECB Interest Rate Decision          | 0.8846 | 394350744214.5117 |       39
# EUR        | ECB M3 Money Supply y/y             | 0.9034 | 789890153613.2191 |       49
# EUR        | ECB Marginal Lending Facility Rate  | 0.8758 | 417182390182.8782 |       37
# EUR        | ECB Non-Financial Corporations Loan | 0.7923 | 1044958094459.8451 |       30
# EUR        | ECB Private Sector Loans y/y        | 0.7605 | 579379474765.7401 |       30
# EUR        | Economic Sentiment Indicator        | 0.7759 | 16589132382358.0664 |       49
# EUR        | Employment Change q/q               | -0.7427 | 26968427308.7965 |       20
# EUR        | Employment Change y/y               | 0.7656 | 49896068526.3789 |       20
# EUR        | Employment Level                    | 0.0106 | 2060377492441.9268 |        9
# EUR        | Export Price Index m/m              | -0.2399 | 102778979564.3047 |       22
# EUR        | Export Price Index y/y              | 0.3708 | 2682783378734.5513 |       22
# EUR        | Exports                             | -0.4754 | 4185626793242.9272 |       39
# EUR        | Exports m/m                         | -0.5899 | 12559800965051.0449 |       37
# EUR        | Factory Orders m/m                  | -0.4613 | 31903800188866.2539 |       50
# EUR        | Factory Orders y/y                  | 0.4289 | 152275481335221.8125 |       50
# EUR        | GDP q/q                             | -0.4697 | 865102212677.2007 |      178
# EUR        | GDP y/y                             | 0.2908 | 2586588901496.7344 |      158
# EUR        | GfK Consumer Climate                | 0.7892 | 26410461610211.8594 |       50
# EUR        | Government Budget Balance           | 0.0971 | 2776735786836942.0000 |       38
# EUR        | Government Deficit – GDP Ratio      | -0.2086 | 12087590783876.8633 |       10
# EUR        | HICP m/m                            | 0.0362 | 450109046377.7745 |      299
# EUR        | HICP y/y                            | 0.6846 | 2999282921424.2681 |      319
# EUR        | Ifo Business Climate                | 0.7310 | 6729542554927.7148 |       50
# EUR        | Ifo Business Expectations           | 0.6589 | 14176374406062.3809 |       49
# EUR        | Ifo Current Business Situation      | 0.9214 | 1900985624942.3228 |       43
# EUR        | Import Price Index m/m              | 0.0027 | 2083399906798.0291 |       37
# EUR        | Import Price Index y/y              | 0.8475 | 30859654629590.3516 |       37
# EUR        | Imports                             | 0.3246 | 7263940640486.2422 |       39
# EUR        | Imports m/m                         | -0.3459 | 14181138578764.1562 |       37
# EUR        | Industrial Confidence Indicator     | 0.9331 | 6105296521016.9375 |       47
# EUR        | Industrial Investment Forecast      | -0.0221 | 67704568087593.5469 |        5
# EUR        | Industrial New Orders m/m           | -0.2917 | 246217590631120.3438 |       23
# EUR        | Industrial New Orders y/y           | 0.1713 | 150814228264812.0000 |       23
# EUR        | Industrial Production m/m           | -0.9387 | 4079802073255.0835 |      192
# EUR        | Industrial Production y/y           | 0.1682 | 17586840448800.3184 |      192
# EUR        | Industrial Sales  y/y               | 0.8701 | 12011647394593.1113 |       37
# EUR        | Industrial Sales m/m                | -0.7512 | 4565911754517.5117 |       37
# EUR        | Industry Selling Price Expectations | 0.8249 | 30120289342497.6484 |       33
# EUR        | Jobseekers Total                    | 0.5810 | 5477223642113579.0000 |       34
# EUR        | Labour Cost Index                   | -0.5538 | 740451671222.3392 |        9
# EUR        | New Car Registrations m/m           | -0.5794 | 889359951716583.5000 |      100
# EUR        | New Car Registrations y/y           | -0.3259 | 240031876872038.3125 |      100
# EUR        | Nonfarm Payrolls q/q                | 0.3359 | 27070863694.8568 |       24
# EUR        | Official Reserve Assets             | 0.7850 | 4183015939824683.5000 |       29
# EUR        | PPI m/m                             | 0.3140 | 3229312818124.2686 |      194
# EUR        | PPI y/y                             | 0.9329 | 19531424037406.7227 |      196
# EUR        | Quarterly Unemployment Rate         | 0.6146 | 325143737024.0973 |       13
# EUR        | Retail Sales m/m                    | -0.7036 | 3957371180661.4985 |      148
# EUR        | Retail Sales y/y                    | -0.0477 | 20778440474213.5234 |      193
# EUR        | S&P Global Composite PMI            | -0.3644 | 10526698422609.6895 |      275
# EUR        | S&P Global Construction PMI         | -0.1006 | 16490214415768.9727 |       66
# EUR        | S&P Global Manufacturing PMI        | 0.7909 | 7653886198413.7168 |      392
# EUR        | S&P Global Services PMI             | 0.1789 | 11699693078509.4297 |      388
# EUR        | Sentix Investor Confidence          | 0.5744 | 91459406689838.2500 |       47
# EUR        | Services Sentiment Indicator        | 0.1928 | 8320676668198.2041 |       38
# EUR        | Trade Balance                       | -0.0679 | 157609681700225.8125 |      232
# EUR        | Trade Balance EU                    | -0.2148 | 1663557905624.1785 |       37
# EUR        | Trade Balance Non-EU                | 0.4256 | 8677263338729.1738 |       37
# EUR        | Trade Balance n.s.a.                | 0.4993 | 144470375516228.4688 |       83
# EUR        | Unemployment                        | 0.8320 | 3310940110.5684 |       33
# EUR        | Unemployment Change                 | 0.0953 | 1708768420894485.7500 |       93
# EUR        | Unemployment Rate                   | -0.2137 | 4719381746330.1475 |      176
# EUR        | Unemployment n.s.a.                 | 0.7159 | 6981931472.7103 |       33
# EUR        | Wage Costs y/y                      | -0.8995 | 1049158711677.3239 |        8
# EUR        | Wholesale Price Index m/m           | 0.1029 | 1403609877330.3923 |       47
# EUR        | Wholesale Price Index y/y           | 0.8847 | 10175266216541.8770 |       46
# EUR        | ZEW Economic Sentiment Indicator    | 0.7655 | 290178977409944.5625 |      101
# EUR        | ZEW Economic Situation              | 0.7828 | 125379643501750.7969 |       43
# USD        | 10-Year Note Auction                | 0.1875 | 207330899633.1100 |       38
# USD        | 10-Year TIPS Auction                | -0.7785 | 220530556998.9089 |       16
# USD        | 2-Year Note Auction                 | 0.2712 | 293861619850.2388 |       38
# USD        | 20-Year Bond Auction                | -0.1629 | 94139181155.5059 |       13
# USD        | 3-Month Bill Auction                | 0.9676 | 72761170683.3284 |      179
# USD        | 3-Year Note Auction                 | -0.0795 | 222917166214.9564 |       37
# USD        | 30-Year Bond Auction                | 0.5169 | 140634467705.2431 |       38
# USD        | 4-Week Bill Auction                 | 0.9567 | 116554953688.2733 |      178
# USD        | 5-Year Note Auction                 | 0.0744 | 235721991394.8466 |       38
# USD        | 5-Year TIPS Auction                 | -0.7856 | 95803433314.7100 |        7
# USD        | 52-Week Bill Auction                | 0.5886 | 296630778390.1768 |       43
# USD        | 6-Month Bill Auction                | 0.9589 | 71915205549.8069 |      179
# USD        | 7-Year Note Auction                 | 0.1667 | 194017409697.5967 |       37
# USD        | 8-Week Bill Auction                 | 0.7328 | 57835605895.3153 |       99
# USD        | ADP Nonfarm Employment Change       | -22.3950 | 1194394525415990784.0000 |       50
# USD        | Average Hourly Earnings m/m         | -0.5654 | 38831086881.4231 |       51
# USD        | Average Hourly Earnings y/y         | 0.2051 | 555325622854.2883 |       51
# USD        | Average Weekly Hours                | 0.7329 | 12900348976.7333 |       51
# USD        | Baker Hughes US Oil Rig Count       | 0.4626 | 2443808655851253.5000 |      149
# USD        | Baker Hughes US Total Rig Count     | 0.8533 | 160844813837767.7188 |      109
# USD        | Building Permits                    | 0.6729 | 7416821811.0082 |       50
# USD        | Building Permits m/m                | -0.7050 | 32817008713048.5938 |       28
# USD        | Business Inventories m/m            | 0.5435 | 131850906204.5426 |       51
# USD        | CB Consumer Confidence Index        | 0.0667 | 103787236388663.1250 |       51
# USD        | CB Employment Trends Index          | 0.6013 | 6416925774725.1904 |       37
# USD        | CB Leading Economic Index m/m       | 0.5165 | 208833982561.0114 |       51
# USD        | CFTC Aluminium Non-Commercial Net P | 0.8957 | 317709201188.0630 |       87
# USD        | CFTC Copper Non-Commercial Net Posi | 0.8147 | 118231093408878.3750 |      155
# USD        | CFTC Corn Non-Commercial Net Positi | 0.8926 | 3927596256141319.5000 |       96
# USD        | CFTC Crude Oil Non-Commercial Net P | 0.9358 | 841107677992304.7500 |      237
# USD        | CFTC Gold Non-Commercial Net Positi | 0.8254 | 533197888458034.3750 |      225
# USD        | CFTC Nasdaq 100 Non-Commercial Net  | 0.1354 | 124240428464209.1406 |       86
# USD        | CFTC Natural Gas Non-Commercial Net | 0.4370 | 399038711207522.3750 |       95
# USD        | CFTC S&P 500 Non-Commercial Net Pos | 0.7608 | 2999593976506181.0000 |      155
# USD        | CFTC Silver Non-Commercial Net Posi | 0.8083 | 59828712097187.5078 |      226
# USD        | CFTC Soybeans Non-Commercial Net Po | 0.8469 | 1163696640949821.7500 |       96
# USD        | CFTC Wheat Non-Commercial Net Posit | 0.7602 | 177300295923817.7188 |       96
# USD        | CPI                                 | 0.5313 | 39209687533317.1953 |       39
# USD        | CPI m/m                             | 0.1664 | 83693626694.8405 |       51
# USD        | CPI n.s.a.                          | 0.5251 | 39056131357461.1094 |       39
# USD        | CPI n.s.a. m/m                      | 0.0497 | 132973879758.9743 |       39
# USD        | CPI y/y                             | 0.8163 | 844894572823.8364 |       51
# USD        | Challenger Job Cuts                 | 0.1327 | 1850513131916337.7500 |       37
# USD        | Challenger Job Cuts y/y             | 0.4337 | 10122374523085024.0000 |       49
# USD        | Chicago Fed National Activity Index | -10.0524 | 575930698665.8009 |       38
# USD        | Cleveland Fed Median CPI m/m        | 0.4923 | 10823228696.5861 |       36
# USD        | Construction Spending m/m           | 0.0678 | 207694459186.1613 |       49
# USD        | Continuing Jobless Claims           | 0.9737 | 14179545132.9537 |      229
# USD        | Core CPI                            | 0.6525 | 41355769370849.8047 |       39
# USD        | Core CPI m/m                        | 0.0265 | 35532364933.1025 |       51
# USD        | Core CPI n.s.a.                     | 0.6517 | 41087634862584.2812 |       39
# USD        | Core CPI n.s.a. m/m                 | 0.0426 | 34041785764.0991 |       39
# USD        | Core CPI y/y                        | 0.7569 | 375545018540.6688 |       51
# USD        | Core Durable Goods Orders m/m       | -1.0291 | 311580005488.1700 |       50
# USD        | Core PCE Price Index m/m            | -0.0495 | 24752358584.1875 |       50
# USD        | Core PCE Price Index q/q            | 0.3235 | 911399371064.2903 |       47
# USD        | Core PCE Price Index y/y            | 0.7317 | 235338455360.4712 |       49
# USD        | Core PPI m/m                        | 0.2668 | 65131592998.2306 |       52
# USD        | Core PPI y/y                        | 0.8351 | 877981059662.7462 |       51
# USD        | Core Retail Sales m/m               | -0.7647 | 3507505343377.6318 |       51
# USD        | Corporate Profits q/q               | -0.1360 | 13484300812897.1191 |       18
# USD        | Current Account                     | 0.0825 | 1379290310105130.2500 |       13
# USD        | Dallas Fed Manufacturing Index      | 0.0100 | 81513968321907.4844 |       38
# USD        | Dallas Fed Services Business Activi | 0.1290 | 53878391361269.8516 |       33
# USD        | Dallas Fed Services Revenues        | -0.3557 | 29916932941358.5234 |       33
# USD        | Dallas Fed Trimmed Mean PCE Inflati | 0.1606 | 1169278637807.8364 |       33
# USD        | Durable Goods Orders excl. Defense  | -0.5647 | 29785573779503.8086 |       36
# USD        | Durable Goods Orders m/m            | -0.5897 | 17291290063533.0898 |       51
# USD        | EIA Crude Oil Imports Change        | -0.6449 | 2308252181400.3716 |      141
# USD        | EIA Crude Oil Stocks Change         | -0.1506 | 32753589452918.6094 |      226
# USD        | EIA Cushing Crude Oil Stocks Change | 0.1821 | 1339850354508.9526 |      141
# USD        | EIA Distillate Fuel Production Chan | -0.4395 | 55429483539.6547 |      141
# USD        | EIA Distillates Stocks Change       | -0.1189 | 6996364182142.6299 |      173
# USD        | EIA Gasoline Production Change      | -0.5467 | 316887305056.5382 |      141
# USD        | EIA Gasoline Stocks Change          | 0.0412 | 9649112666332.8320 |      196
# USD        | EIA Heating Oil Stocks Change       | -0.4730 | 394034155285.5573 |      141
# USD        | EIA Natural Gas Storage Change      | 0.6323 | 3445755807814051.5000 |      213
# USD        | EIA Refinery Crude Oil Daily Inputs | -0.2494 | 129233446157.6959 |       85
# USD        | EIA Refinery Utilization Rate Chang | -0.1899 | 3199838027841.4858 |       85
# USD        | Employment Benefits q/q             | -0.7471 | 42585727113.4030 |        8
# USD        | Employment Cost Index q/q           | 0.2736 | 17352745527.2351 |       12
# USD        | Employment Wages q/q                | -0.1228 | 19649136434.2179 |        8
# USD        | Existing Home Sales                 | 0.9092 | 74211787987.8061 |       51
# USD        | Existing Home Sales m/m             | -0.3451 | 24214465408905.9609 |       50
# USD        | Export Price Index m/m              | -0.0042 | 1919103300334.5840 |       40
# USD        | Export Price Index y/y              | 0.8290 | 9907117161994.6465 |       39
# USD        | Exports                             | 0.1156 | 69327221101333.2031 |       22
# USD        | Factory Orders excl. Transportation | -0.4752 | 791561609994.6997 |       36
# USD        | Factory Orders m/m                  | -0.5182 | 4856573761584.7529 |       50
# USD        | Fed Capacity Utilization Rate       | 0.5445 | 975146682583.1034 |       51
# USD        | Fed Consumer Credit m/m             | -0.0138 | 180395967174747.7500 |       50
# USD        | Fed Industrial Production m/m       | -1.1053 | 705622589054.9683 |       51
# USD        | Fed Industrial Production y/y       | -0.7414 | 1181871710890.3450 |       21
# USD        | Fed Interest Rate Decision          | 0.8787 | 566238844648.5581 |       34
# USD        | Fed Labor Market Conditions Index   | -1.1232 | 2169689641614.6064 |        8
# USD        | Fed Manufacturing Production m/m    | -1.3778 | 709343800001.0713 |       34
# USD        | Federal Budget Balance              | -0.4474 | 40118371348778080.0000 |       49
# USD        | GDP Price Index q/q                 | 0.6615 | 1528512854997.7585 |       48
# USD        | GDP Sales q/q                       | -0.1179 | 3415665684396.1558 |       22
# USD        | GDP q/q                             | 0.0645 | 5305878606336.6445 |       49
# USD        | Goods Trade Balance                 | 0.3793 | 246915116222223.4375 |       29
# USD        | Government Payrolls                 | -0.7896 | 4866090419654850.0000 |       49
# USD        | HPI                                 | 0.2194 | 192828923864296.3125 |       36
# USD        | HPI m/m                             | 0.5184 | 206287343869.9653 |       49
# USD        | HPI y/y                             | 0.8140 | 3111114949567.2241 |       36
# USD        | Housing Starts                      | 0.4144 | 11548360491.7752 |       50
# USD        | Housing Starts m/m                  | -0.5171 | 132924771623190.2188 |       28
# USD        | ISM Manufacturing Employment        | -0.0935 | 6487324334871.3164 |       36
# USD        | ISM Manufacturing New Orders        | -0.1869 | 8589191667222.8213 |       36
# USD        | ISM Manufacturing PMI               | 0.9071 | 2684591852556.8159 |       51
# USD        | ISM Manufacturing Prices Paid       | 0.6263 | 60788673836182.5938 |       44
# USD        | ISM Non-Manufacturing Business Acti | -0.3040 | 14014848490112.4355 |       36
# USD        | ISM Non-Manufacturing Employment    | -0.2115 | 7692247674914.8555 |       36
# USD        | ISM Non-Manufacturing New Orders    | 0.0028 | 15215503197975.8516 |       36
# USD        | ISM Non-Manufacturing PMI           | 0.6565 | 7760752706074.3945 |       51
# USD        | ISM Non-Manufacturing Prices Paid   | 0.6367 | 12917758301842.2949 |       36
# USD        | ISM-NY Business Conditions Index    | 0.7323 | 271525875554476.5000 |       24
# USD        | ISM-NY Current Business Conditions  | 0.0128 | 228484319964980.6562 |       19
# USD        | Import Price Index excl. Petroleum  | -0.4146 | 85726243983.4743 |       22
# USD        | Import Price Index m/m              | -0.0836 | 579201275830.9202 |       51
# USD        | Import Price Index y/y              | 0.7730 | 7049488841265.2148 |       51
# USD        | Imports                             | 0.5513 | 357250148900446.3750 |       22
# USD        | Initial Jobless Claims              | 0.9501 | 1165433581583842.0000 |      234
# USD        | Initial Jobless Claims 4-Week Avera | -0.8565 | 477704302295473.8750 |      171
# USD        | JOLTS Job Openings                  | 0.9079 | 137959562769.9363 |       36
# USD        | Kansas City Fed Manufacturing Compo | 0.3529 | 32273506588866.7031 |       36
# USD        | Kansas City Fed Manufacturing Produ | -0.4581 | 118786886430617.2812 |       36
# USD        | MNI Chicago Business Barometer      | 0.7910 | 23048240890887.3906 |       50
# USD        | Manufacturing Payrolls              | -12.0743 | 3530809645498712.5000 |       33
# USD        | Michigan 5-Year Inflation Expectati | 0.7727 | 37385710534.7202 |       70
# USD        | Michigan Consumer Expectations      | 0.6970 | 24632217491569.3516 |       75
# USD        | Michigan Consumer Sentiment         | 0.7280 | 18644686204345.5781 |       99
# USD        | Michigan Current Conditions         | 0.5693 | 23073977890768.3750 |       77
# USD        | Michigan Inflation Expectations     | 0.7701 | 256381540679.6017 |       92
# USD        | NAHB Housing Market Index           | 0.8546 | 41795982900026.1562 |       50
# USD        | NFIB Small Business Optimism        | 0.5320 | 7108042778483.5967 |       40
# USD        | NY Fed Empire State Manufacturing I | 0.1277 | 305019486857534.0000 |       50
# USD        | New Home Sales                      | 0.2638 | 4876846432.4036 |       51
# USD        | New Home Sales m/m                  | -0.4889 | 134767322482111.5938 |       50
# USD        | Nondefense Capital Goods Orders exc | -0.6048 | 486786798893.9692 |       36
# USD        | Nondefense Capital Goods Shipments  | -0.5536 | 228511121175.9474 |       48
# USD        | Nonfarm Payrolls                    | -25.8639 | 995040426540560512.0000 |       52
# USD        | Nonfarm Productivity q/q            | -0.0301 | 14301637741004.2949 |       31
# USD        | PCE Price Index m/m                 | 0.0223 | 50938603169.4817 |       50
# USD        | PCE Price Index q/q                 | 0.7691 | 703422873735.1707 |       37
# USD        | PCE Price Index y/y                 | 0.8755 | 311304603119.5729 |       46
# USD        | PPI m/m                             | 0.1884 | 172121448136.0098 |       52
# USD        | PPI y/y                             | 0.8266 | 2077918698764.1707 |       52
# USD        | Participation Rate                  | 0.1881 | 27114040817.1211 |       36
# USD        | Pending Home Sales Index            | -0.0670 | 17822770562195.1836 |       33
# USD        | Pending Home Sales m/m              | -0.4925 | 32301123266601.2148 |       50
# USD        | Pending Home Sales y/y              | 0.6740 | 42245920873512.4297 |       38
# USD        | Personal Income m/m                 | -0.6461 | 20425698903550.3047 |       50
# USD        | Personal Spending m/m               | -2.8189 | 571096943207.2678 |       39
# USD        | Philadelphia Fed Business Condition | 0.3796 | 225007888561411.8438 |       37
# USD        | Philadelphia Fed Capex Index        | 0.1623 | 88716392683105.4219 |       37
# USD        | Philadelphia Fed Employment         | 0.4166 | 74422451750922.9531 |       37
# USD        | Philadelphia Fed Manufacturing Inde | 0.4840 | 204603793616841.6875 |       52
# USD        | Philadelphia Fed New Orders         | 0.0101 | 281637776863879.8125 |       37
# USD        | Philadelphia Fed Prices Paid        | 0.6232 | 100323374667310.1406 |       37
# USD        | Private Nonfarm Payrolls            | -37.3367 | 904627567128212096.0000 |       48
# USD        | Real Earnings m/m                   | -0.6819 | 180336337151.2882 |       36
# USD        | Real PCE m/m                        | -3.7746 | 452257670952.5662 |       36
# USD        | Real PCE q/q                        | -2.1807 | 3725527503815.4048 |       35
# USD        | Retail Control m/m                  | -1.7887 | 782739564042.1387 |       33
# USD        | Retail Inventories excl. Autos m/m  | -0.0315 | 132280406855.5198 |       55
# USD        | Retail Inventories m/m              | -0.1926 | 166799549843.9249 |       54
# USD        | Retail Sales excl. Autos and Gas m/ | -1.5608 | 836314503149.8682 |       34
# USD        | Retail Sales m/m                    | -0.6352 | 4315106840217.3867 |       51
# USD        | Retail Sales y/y                    | 0.4451 | 43576275721088.1484 |       51
# USD        | Richmond Fed Manufacturing Index    | 0.4381 | 67678939790787.3516 |       48
# USD        | Richmond Fed Manufacturing Shipment | -0.2260 | 105645159125240.4375 |       33
# USD        | Richmond Fed Services Revenues      | -0.1694 | 95819284071302.4844 |       33
# USD        | S&P Global Composite PMI            | 0.4992 | 5592575865300.0898 |       68
# USD        | S&P Global Manufacturing PMI        | 0.8750 | 2379901129800.8140 |       75
# USD        | S&P Global Services PMI             | 0.5565 | 6122332025138.0615 |       70
# USD        | S&P/CS HPI Composite-20 n.s.a. m/m  | 0.2860 | 747795438266.7552 |       36
# USD        | S&P/CS HPI Composite-20 s.a. m/m    | 0.3631 | 317628094884.8328 |       36
# USD        | S&P/CS HPI Composite-20 y/y         | 0.8417 | 8590278277997.0410 |       47
# USD        | TIC Net Foreign Purchases of Domest | -0.4102 | 2237985425608116.7500 |       34
# USD        | TIC Net Long-Term Transactions      | -0.3409 | 4940854302996724.0000 |       47
# USD        | TIC Net Long-Term Transactions incl | -0.2448 | 5718974391385187.0000 |       47
# USD        | TIC Overall Net Capital Flow        | -0.2672 | 14136863906484160.0000 |       48
# USD        | Trade Balance                       | 0.2943 | 197808868572591.7188 |       51
# USD        | U6 Unemployment Rate                | 0.6853 | 148776254848.9478 |       48
# USD        | Unemployment Rate                   | 0.8424 | 72374552564.6244 |       51
# USD        | Unit Labor Costs q/q                | 0.0967 | 13088105526727.7695 |       31
# USD        | Wholesale Inventories m/m           | 0.7451 | 129284538745.4983 |       76
# USD        | Wholesale Sales m/m                 | -0.4071 | 2931383192274.7778 |       52
# ZAR        | Absa Manufacturing PMI              | -0.1289 | 11449742368393.6484 |       33
# ZAR        | Building Permits m/m                | -0.6432 | 354061110190567.3750 |       43
# ZAR        | Building Permits y/y                | -0.8411 | 621174475999785.0000 |       43
# ZAR        | CFTC ZAR Non-Commercial Net Positio | 0.7286 | 30722932205805.1250 |       81
# ZAR        | CPI m/m                             | -0.2255 | 187229576963.6304 |       37
# ZAR        | CPI y/y                             | 0.8549 | 373701508422.6993 |       38
# ZAR        | Core CPI m/m                        | -0.2593 | 111287490519.9495 |       34
# ZAR        | Core CPI y/y                        | 0.7895 | 93859480136.3020 |       34
# ZAR        | Current Account                     | -0.6048 | 4075447415993687.0000 |        8
# ZAR        | Current Account - GDP Ratio         | -0.6729 | 843789893215.3701 |        8
# ZAR        | GDP q/q                             | -46.5637 | 3916590436404.6440 |        8
# ZAR        | GDP y/y                             | -2.1074 | 1336190711966.2844 |        8
# ZAR        | Gold Production y/y                 | 0.4310 | 88685647541413.3594 |       35
# ZAR        | Gross International Reserves        | 0.7200 | 1366764771163.8774 |       34
# ZAR        | Manufacturing Production m/m        | -1.1920 | 10163926189934.0176 |       36
# ZAR        | Manufacturing Production y/y        | -0.3755 | 14541531956508.5703 |       36
# ZAR        | Mining Production m/m               | -0.5942 | 13010256703179.0098 |       35
# ZAR        | Mining Production y/y               | 0.0158 | 19851011524542.6836 |       35
# ZAR        | Net International Reserves          | 0.8861 | 1147669202074.0366 |       34
# ZAR        | PPI m/m                             | 0.1744 | 551293307166.1807 |       38
# ZAR        | PPI y/y                             | 0.8868 | 3322549948260.0444 |       34
# ZAR        | Retail Sales m/m                    | -0.6168 | 1577620716702.9670 |       38
# ZAR        | Retail Sales y/y                    | 0.2283 | 6280575292761.9043 |       38
# ZAR        | S&P Global PMI                      | -0.5840 | 1607412211868.5432 |       34
# ZAR        | SARB Interest Rate Decision         | -0.4006 | 891785446333.8127 |       16
# ZAR        | SARB M3 Money Supply y/y            | 0.6013 | 1232795668856.8103 |       34
# ZAR        | SARB Prime Rate                     | -0.4006 | 891785446333.8127 |       16
# ZAR        | SARB Private Sector Credit y/y      | 0.7334 | 961303936250.0059 |       33
# ZAR        | Total New Vehicle Sales             | -0.2974 | 14627523318005.8574 |       33
# ZAR        | Total New Vehicle Sales m/m         | -0.9020 | 140282393545209.9375 |       15
# ZAR        | Total New Vehicle Sales y/y         | -0.8248 | 153288679763088.4688 |       33
# ZAR        | Trade Balance                       | -0.1765 | 205598994034608.3438 |       39
# ZAR        | Unemployment                        | -2.0789 | 93722003202.5789 |        9
# ZAR        | Unemployment Rate                   | -0.8181 | 462698053868.4961 |       10
#
# ✅ Accuracy summary saved to: C:\Users\Nokul\Desktop\Codes\Python Codes\News Data\event_rnn_evaluation_summary.csv
#
# === Forecast for This/Next Month ===
# C:\Users\Nokul\AppData\Local\Temp\ipykernel_3032\3303005374.py:238: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.no_grad(), autocast():
# C:\Users\Nokul\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\amp\autocast_mode.py:266: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# EUR - 10-Year BTP Auction                : 🔮 Forecast for THIS month = 3459141.18
# EUR - 10-Year Bond Auction               : 🔮 Forecast for THIS month = 2361680.30
# EUR - 10-Year OAT Auction                : 🔮 Forecast for THIS month = 3074328.04
# EUR - 10-Year Obligacion Auction         : 🔮 Forecast for THIS month = 3186863.76
# EUR - 12-Month BOT Auction               : 🔮 Forecast for THIS month = 1998498.41
# EUR - 12-Month BTF Auction               : 🔮 Forecast for THIS month = 1841767.77
# EUR - 12-Month Letras Auction            : 🔮 Forecast for THIS month = 1869169.17
# EUR - 15-Year Obligacion Auction         : 🔮 Forecast for THIS month = 3450767.84
# EUR - 2-Year CTZ Auction                 : 🔮 Forecast for THIS month = 2106620.24
# EUR - 2-Year Note Auction                : 🔮 Forecast for THIS month = 1741064.05
# EUR - 3-Month BTF Auction                : 🔮 Forecast for THIS month = 1869240.35
# EUR - 3-Month Letras Auction             : 🔮 Forecast for THIS month = 1939629.28
# EUR - 3-Year BTP Auction                 : 🔮 Forecast for THIS month = 2094687.83
# EUR - 3-Year Bonos Auction               : 🔮 Forecast for THIS month = 2149456.56
# EUR - 3-Year OAT Auction                 : 🔮 Forecast for THIS month = 2245405.46
# EUR - 30-Year BTP Auction                : 🔮 Forecast for THIS month = 4332125.89
# EUR - 30-Year Bond Auction               : 🔮 Forecast for THIS month = 2793284.59
# EUR - 30-Year Obligacion Auction         : 🔮 Forecast for THIS month = 3828019.36
# EUR - 5-Year BTP Auction                 : 🔮 Forecast for THIS month = 2755839.47
# EUR - 5-Year Bonos Auction               : 🔮 Forecast for THIS month = 2367488.67
# EUR - 5-Year Note Auction                : 🔮 Forecast for THIS month = 1946974.02
# EUR - 5-Year OAT Auction                 : 🔮 Forecast for THIS month = 2569126.14
# EUR - 50-Year Obligacion Auction         : 🔮 Forecast for THIS month = 2782054.46
# EUR - 6-Month BOT Auction                : 🔮 Forecast for THIS month = 2088219.50
# EUR - 6-Month BTF Auction                : 🔮 Forecast for THIS month = 1867250.44
# EUR - 6-Month Letras Auction             : 🔮 Forecast for THIS month = 1924057.39
# EUR - 7-Year BTP Auction                 : 🔮 Forecast for THIS month = 3003814.86
# EUR - 9-Month Letras Auction             : 🔮 Forecast for THIS month = 1939777.53
# EUR - Business Climate                   : 🔮 Forecast for THIS month = 96260884.76
# EUR - Business Climate Indicator         : 🔮 Forecast for THIS month = -728639.07
# EUR - Business Confidence                : 🔮 Forecast for THIS month = 37261972.45
# EUR - CFTC EUR Non-Commercial Net Positio: 🔮 Forecast for THIS month = 73039994.43
# EUR - CPI                                : 🔮 Forecast for THIS month = 127437063.36
# EUR - CPI FOI excl. Tobacco m/m          : 🔮 Forecast for THIS month = -41381.55
# EUR - CPI FOI excl. Tobacco y/y          : 🔮 Forecast for THIS month = 1374571.40
# EUR - CPI excl. Energy and Unprocessed Fo: 🔮 Forecast for THIS month = 298678.30
# EUR - CPI excl. Energy and Unprocessed Fo: 🔮 Forecast for THIS month = 2399927.07
# EUR - CPI excl. Tobacco m/m              : 🔮 Forecast for THIS month = 168202.13
# EUR - CPI excl. Tobacco y/y              : 🔮 Forecast for THIS month = 1892761.47
# EUR - CPI m/m                            : 🔮 Forecast for THIS month = -58311.50
# EUR - CPI y/y                            : 🔮 Forecast for THIS month = 1598725.01
# EUR - Construction Output m/m            : 🔮 Forecast for THIS month = -461700.92
# EUR - Construction Output y/y            : 🔮 Forecast for THIS month = -1510241.53
# EUR - Consumer Confidence                : 🔮 Forecast for THIS month = 91021812.57
# EUR - Consumer Confidence Index          : 🔮 Forecast for THIS month = 44687365.15
# EUR - Consumer Price Expectations        : 🔮 Forecast for THIS month = 23327938.87
# EUR - Consumer Spending m/m              : 🔮 Forecast for THIS month = -849682.21
# EUR - Core CPI                           : 🔮 Forecast for THIS month = 121082256.60
# EUR - Core CPI m/m                       : 🔮 Forecast for THIS month = 260886.76
# EUR - Core CPI y/y                       : 🔮 Forecast for THIS month = 2317240.97
# EUR - Current Account                    : 🔮 Forecast for THIS month = 8922737.90
# EUR - Current Account n.s.a.             : 🔮 Forecast for THIS month = 22567702.56
# EUR - ECB Deposit Facility Rate Decision : 🔮 Forecast for THIS month = 2233110.37
# EUR - ECB Households Loans y/y           : 🔮 Forecast for THIS month = 1455751.57
# EUR - ECB Interest Rate Decision         : 🔮 Forecast for THIS month = 2403293.07
# EUR - ECB M3 Money Supply y/y            : 🔮 Forecast for THIS month = 3597579.73
# EUR - ECB Marginal Lending Facility Rate : 🔮 Forecast for THIS month = 2656014.50
# EUR - ECB Non-Financial Corporations Loan: 🔮 Forecast for THIS month = 2098961.38
# EUR - ECB Private Sector Loans y/y       : 🔮 Forecast for THIS month = 2357586.55
# EUR - ECB Targeted LTRO                  : 🔮 Forecast for THIS month = 150213362.52
# EUR - Economic Sentiment Indicator       : 🔮 Forecast for THIS month = 93590548.99
# EUR - Employment Change q/q              : 🔮 Forecast for THIS month = 109615.68
# EUR - Employment Change y/y              : 🔮 Forecast for THIS month = 675842.19
# EUR - Employment Level                   : 🔮 Forecast for THIS month = 170575356.58
# EUR - Export Price Index m/m             : 🔮 Forecast for THIS month = -219084.84
# EUR - Export Price Index y/y             : 🔮 Forecast for THIS month = 1277742.29
# EUR - Exports                            : 🔮 Forecast for THIS month = 48841266.95
# EUR - Exports m/m                        : 🔮 Forecast for THIS month = -1213010.97
# EUR - Factory Orders m/m                 : 🔮 Forecast for THIS month = -1370189.78
# EUR - Factory Orders y/y                 : 🔮 Forecast for THIS month = 818375.51
# EUR - GDP q/q                            : 🔮 Forecast for THIS month = -364172.51
# EUR - GDP y/y                            : 🔮 Forecast for THIS month = -172281.82
# EUR - GfK Consumer Climate               : 🔮 Forecast for THIS month = -22311341.18
# EUR - Government Budget Balance          : 🔮 Forecast for THIS month = -76741510.39
# EUR - Government Deficit – GDP Ratio     : 🔮 Forecast for THIS month = 2914434.24
# EUR - HICP m/m                           : 🔮 Forecast for THIS month = -144074.59
# EUR - HICP y/y                           : 🔮 Forecast for THIS month = 1460093.85
# EUR - Ifo Business Climate               : 🔮 Forecast for THIS month = 85851514.16
# EUR - Ifo Business Expectations          : 🔮 Forecast for THIS month = 86276017.76
# EUR - Ifo Current Business Situation     : 🔮 Forecast for THIS month = 85432879.54
# EUR - Import Price Index m/m             : 🔮 Forecast for THIS month = -826424.91
# EUR - Import Price Index y/y             : 🔮 Forecast for THIS month = 406145.57
# EUR - Imports                            : 🔮 Forecast for THIS month = 56404801.94
# EUR - Imports m/m                        : 🔮 Forecast for THIS month = 544686.20
# EUR - Industrial Confidence Indicator    : 🔮 Forecast for THIS month = -12262854.50
# EUR - Industrial Investment Forecast     : 🔮 Forecast for THIS month = 7083837.99
# EUR - Industrial New Orders m/m          : 🔮 Forecast for THIS month = -1176138.23
# EUR - Industrial New Orders y/y          : 🔮 Forecast for THIS month = -78907.72
# EUR - Industrial Production m/m          : 🔮 Forecast for THIS month = -2129542.97
# EUR - Industrial Production y/y          : 🔮 Forecast for THIS month = -2321460.37
# EUR - Industrial Sales  y/y              : 🔮 Forecast for THIS month = -3526053.33
# EUR - Industrial Sales m/m               : 🔮 Forecast for THIS month = -1366687.95
# EUR - Industry Selling Price Expectations: 🔮 Forecast for THIS month = 8503686.33
# EUR - Jobseekers Total                   : 🔮 Forecast for THIS month = 3115926456.36
# EUR - Labour Cost Index                  : 🔮 Forecast for THIS month = 3624264.22
# EUR - New Car Registrations m/m          : 🔮 Forecast for THIS month = -10998797.61
# EUR - New Car Registrations y/y          : 🔮 Forecast for THIS month = -15774015.67
# EUR - Nonfarm Payrolls q/q               : 🔮 Forecast for THIS month = -193055.77
# EUR - Official Reserve Assets            : 🔮 Forecast for THIS month = 1449109564.92
# EUR - PPI m/m                            : 🔮 Forecast for THIS month = -1962175.70
# EUR - PPI y/y                            : 🔮 Forecast for THIS month = 803754.97
# EUR - Quarterly Unemployment Rate        : 🔮 Forecast for THIS month = 6323645.01
# EUR - Retail Sales m/m                   : 🔮 Forecast for THIS month = -270296.67
# EUR - Retail Sales y/y                   : 🔮 Forecast for THIS month = 1458408.68
# EUR - S&P Global Composite PMI           : 🔮 Forecast for THIS month = 47630265.36
# EUR - S&P Global Construction PMI        : 🔮 Forecast for THIS month = 44966911.31
# EUR - S&P Global Manufacturing PMI       : 🔮 Forecast for THIS month = 48418339.76
# EUR - S&P Global Services PMI            : 🔮 Forecast for THIS month = 47007438.85
# EUR - Sentix Investor Confidence         : 🔮 Forecast for THIS month = -10589664.26
# EUR - Services Sentiment Indicator       : 🔮 Forecast for THIS month = 580845.58
# EUR - Trade Balance                      : 🔮 Forecast for THIS month = 2968883.80
# EUR - Trade Balance EU                   : 🔮 Forecast for THIS month = -811815.57
# EUR - Trade Balance Non-EU               : 🔮 Forecast for THIS month = 3315061.35
# EUR - Trade Balance n.s.a.               : 🔮 Forecast for THIS month = 12989641.79
# EUR - Unemployment                       : 🔮 Forecast for THIS month = 2898978.56
# EUR - Unemployment Change                : 🔮 Forecast for THIS month = -18671893.60
# EUR - Unemployment Rate                  : 🔮 Forecast for THIS month = 6125946.05
# EUR - Unemployment n.s.a.                : 🔮 Forecast for THIS month = 2879630.22
# EUR - Wage Costs y/y                     : 🔮 Forecast for THIS month = 3605052.40
# EUR - Wholesale Price Index m/m          : 🔮 Forecast for THIS month = -453455.35
# EUR - Wholesale Price Index y/y          : 🔮 Forecast for THIS month = 211930.27
# EUR - ZEW Economic Sentiment Indicator   : 🔮 Forecast for THIS month = 32441394.53
# EUR - ZEW Economic Situation             : 🔮 Forecast for THIS month = -80093722.02
# USD - 10-Year Note Auction               : 🔮 Forecast for THIS month = 4192003.66
# USD - 10-Year TIPS Auction               : 🔮 Forecast for THIS month = 1969125.42
# USD - 2-Year Note Auction                : 🔮 Forecast for THIS month = 3821627.03
# USD - 20-Year Bond Auction               : 🔮 Forecast for THIS month = 4728126.70
# USD - 3-Month Bill Auction               : 🔮 Forecast for THIS month = 4064891.37
# USD - 3-Year Note Auction                : 🔮 Forecast for THIS month = 3767091.48
# USD - 30-Year Bond Auction               : 🔮 Forecast for THIS month = 4635164.90
# USD - 30-Year TIPS Auction               : 🔮 Forecast for THIS month = 1947384.29
# USD - 4-Week Bill Auction                : 🔮 Forecast for THIS month = 3971925.81
# USD - 5-Year Note Auction                : 🔮 Forecast for THIS month = 3933892.64
# USD - 5-Year TIPS Auction                : 🔮 Forecast for THIS month = 1632730.90
# USD - 52-Week Bill Auction               : 🔮 Forecast for THIS month = 3754520.50
# USD - 6-Month Bill Auction               : 🔮 Forecast for THIS month = 3969749.05
# USD - 7-Year Note Auction                : 🔮 Forecast for THIS month = 4030316.19
# USD - 8-Week Bill Auction                : 🔮 Forecast for THIS month = 4103660.70
# USD - ADP Nonfarm Employment Change      : 🔮 Forecast for THIS month = -1021541967.15
# USD - Average Hourly Earnings m/m        : 🔮 Forecast for THIS month = 268570.82
# USD - Average Hourly Earnings y/y        : 🔮 Forecast for THIS month = 3716960.99
# USD - Average Weekly Hours               : 🔮 Forecast for THIS month = 34219631.31
# USD - Baker Hughes US Oil Rig Count      : 🔮 Forecast for THIS month = 431727427.04
# USD - Baker Hughes US Total Rig Count    : 🔮 Forecast for THIS month = 548042619.26
# USD - Building Permits                   : 🔮 Forecast for THIS month = 1423722.45
# USD - Building Permits m/m               : 🔮 Forecast for THIS month = -1088137.60
# USD - Business Inventories m/m           : 🔮 Forecast for THIS month = -13715.79
# USD - CB Consumer Confidence Index       : 🔮 Forecast for THIS month = 86467322.13
# USD - CB Employment Trends Index         : 🔮 Forecast for THIS month = 105167423.19
# USD - CB Leading Economic Index m/m      : 🔮 Forecast for THIS month = -867820.84
# USD - CFTC Aluminium Non-Commercial Net P: 🔮 Forecast for THIS month = 313469.17
# USD - CFTC Copper Non-Commercial Net Posi: 🔮 Forecast for THIS month = 20792175.25
# USD - CFTC Corn Non-Commercial Net Positi: 🔮 Forecast for THIS month = -51662653.04
# USD - CFTC Crude Oil Non-Commercial Net P: 🔮 Forecast for THIS month = 169950876.78
# USD - CFTC Gold Non-Commercial Net Positi: 🔮 Forecast for THIS month = 171672673.39
# USD - CFTC Nasdaq 100 Non-Commercial Net : 🔮 Forecast for THIS month = 11515212.13
# USD - CFTC Natural Gas Non-Commercial Net: 🔮 Forecast for THIS month = -118856726.41
# USD - CFTC S&P 500 Non-Commercial Net Pos: 🔮 Forecast for THIS month = -108585281.56
# USD - CFTC Silver Non-Commercial Net Posi: 🔮 Forecast for THIS month = 56278604.21
# USD - CFTC Soybeans Non-Commercial Net Po: 🔮 Forecast for THIS month = 53490956.31
# USD - CFTC Wheat Non-Commercial Net Posit: 🔮 Forecast for THIS month = -99328284.13
# USD - CPI                                : 🔮 Forecast for THIS month = 315019041.88
# USD - CPI m/m                            : 🔮 Forecast for THIS month = 101088.51
# USD - CPI n.s.a.                         : 🔮 Forecast for THIS month = 315477358.33
# USD - CPI n.s.a. m/m                     : 🔮 Forecast for THIS month = 146776.64
# USD - CPI y/y                            : 🔮 Forecast for THIS month = 2355182.08
# USD - Challenger Job Cuts                : 🔮 Forecast for THIS month = 116949190.08
# USD - Challenger Job Cuts y/y            : 🔮 Forecast for THIS month = 62037817.50
# USD - Chicago Fed National Activity Index: 🔮 Forecast for THIS month = -894010.14
# USD - Cleveland Fed Median CPI m/m       : 🔮 Forecast for THIS month = 243263.92
# USD - Construction Spending m/m          : 🔮 Forecast for THIS month = -236416.64
# USD - Continuing Jobless Claims          : 🔮 Forecast for THIS month = 1829861.03
# USD - Core CPI                           : 🔮 Forecast for THIS month = 320824572.75
# USD - Core CPI m/m                       : 🔮 Forecast for THIS month = 115965.12
# USD - Core CPI n.s.a.                    : 🔮 Forecast for THIS month = 321174140.81
# USD - Core CPI n.s.a. m/m                : 🔮 Forecast for THIS month = 168576.19
# USD - Core CPI y/y                       : 🔮 Forecast for THIS month = 2760939.04
# USD - Core Durable Goods Orders m/m      : 🔮 Forecast for THIS month = -118609.88
# USD - Core PCE Price Index m/m           : 🔮 Forecast for THIS month = 123909.18
# USD - Core PCE Price Index q/q           : 🔮 Forecast for THIS month = 2716760.77
# USD - Core PCE Price Index y/y           : 🔮 Forecast for THIS month = 2528369.33
# USD - Core PPI m/m                       : 🔮 Forecast for THIS month = -80796.65
# USD - Core PPI y/y                       : 🔮 Forecast for THIS month = 2989877.52
# USD - Core Retail Sales m/m              : 🔮 Forecast for THIS month = -682011.80
# USD - Corporate Profits q/q              : 🔮 Forecast for THIS month = -1102934.84
# USD - Current Account                    : 🔮 Forecast for THIS month = -287922703.72
# USD - Dallas Fed Manufacturing Index     : 🔮 Forecast for THIS month = -19205986.99
# USD - Dallas Fed Services Business Activi: 🔮 Forecast for THIS month = -11629310.79
# USD - Dallas Fed Services Revenues       : 🔮 Forecast for THIS month = -1789855.77
# USD - Dallas Fed Trimmed Mean PCE Inflati: 🔮 Forecast for THIS month = 2333560.18
# USD - Durable Goods Orders excl. Defense : 🔮 Forecast for THIS month = -1527349.85
# USD - Durable Goods Orders m/m           : 🔮 Forecast for THIS month = -1339300.63
# USD - EIA Crude Oil Imports Change       : 🔮 Forecast for THIS month = 75349.24
# USD - EIA Crude Oil Stocks Change        : 🔮 Forecast for THIS month = -3919535.54
# USD - EIA Cushing Crude Oil Stocks Change: 🔮 Forecast for THIS month = -390938.34
# USD - EIA Distillate Fuel Production Chan: 🔮 Forecast for THIS month = -30114.97
# USD - EIA Distillates Stocks Change      : 🔮 Forecast for THIS month = 742188.72
# USD - EIA Gasoline Production Change     : 🔮 Forecast for THIS month = 119893.13
# USD - EIA Gasoline Stocks Change         : 🔮 Forecast for THIS month = 508135.20
# USD - EIA Heating Oil Stocks Change      : 🔮 Forecast for THIS month = 84748.09
# USD - EIA Natural Gas Storage Change     : 🔮 Forecast for THIS month = 87072776.08
# USD - EIA Refinery Crude Oil Daily Inputs: 🔮 Forecast for THIS month = 73588.64
# USD - EIA Refinery Utilization Rate Chang: 🔮 Forecast for THIS month = 242467.25
# USD - Employment Benefits q/q            : 🔮 Forecast for THIS month = 934961.32
# USD - Employment Cost Index q/q          : 🔮 Forecast for THIS month = 853354.22
# USD - Employment Wages q/q               : 🔮 Forecast for THIS month = 816660.31
# USD - Existing Home Sales                : 🔮 Forecast for THIS month = 4045899.35
# USD - Existing Home Sales m/m            : 🔮 Forecast for THIS month = -1481120.16
# USD - Export Price Index m/m             : 🔮 Forecast for THIS month = -464875.51
# USD - Export Price Index y/y             : 🔮 Forecast for THIS month = 1319968.15
# USD - Exports                            : 🔮 Forecast for THIS month = 277366334.91
# USD - Factory Orders excl. Transportation: 🔮 Forecast for THIS month = -528133.31
# USD - Factory Orders m/m                 : 🔮 Forecast for THIS month = -693566.38
# USD - Fed Capacity Utilization Rate      : 🔮 Forecast for THIS month = 76972197.53
# USD - Fed Consumer Credit m/m            : 🔮 Forecast for THIS month = 6764162.32
# USD - Fed Industrial Production m/m      : 🔮 Forecast for THIS month = -516224.38
# USD - Fed Industrial Production y/y      : 🔮 Forecast for THIS month = 37572.58
# USD - Fed Interest Rate Decision         : 🔮 Forecast for THIS month = 4397974.82
# USD - Fed Labor Market Conditions Index  : 🔮 Forecast for THIS month = 1588789.15
# USD - Fed Manufacturing Production m/m   : 🔮 Forecast for THIS month = -479571.68
# USD - Federal Budget Balance             : 🔮 Forecast for THIS month = -189030753.87
# USD - GDP Price Index q/q                : 🔮 Forecast for THIS month = 2842515.33
# USD - GDP Sales q/q                      : 🔮 Forecast for THIS month = -1943170.36
# USD - GDP q/q                            : 🔮 Forecast for THIS month = -806625.11
# USD - Goods Trade Balance                : 🔮 Forecast for THIS month = -122855635.84
# USD - Government Payrolls                : 🔮 Forecast for THIS month = -34417600.15
# USD - HPI                                : 🔮 Forecast for THIS month = 424144663.19
# USD - HPI m/m                            : 🔮 Forecast for THIS month = 16244.66
# USD - HPI y/y                            : 🔮 Forecast for THIS month = 4045548.44
# USD - Housing Starts                     : 🔮 Forecast for THIS month = 1342264.60
# USD - Housing Starts m/m                 : 🔮 Forecast for THIS month = -4416369.69
# USD - ISM Manufacturing Employment       : 🔮 Forecast for THIS month = 45516649.48
# USD - ISM Manufacturing New Orders       : 🔮 Forecast for THIS month = 46889122.11
# USD - ISM Manufacturing PMI              : 🔮 Forecast for THIS month = 48070456.97
# USD - ISM Manufacturing Prices Paid      : 🔮 Forecast for THIS month = 65204800.99
# USD - ISM Non-Manufacturing Business Acti: 🔮 Forecast for THIS month = 51780764.45
# USD - ISM Non-Manufacturing Employment   : 🔮 Forecast for THIS month = 49069055.77
# USD - ISM Non-Manufacturing New Orders   : 🔮 Forecast for THIS month = 48951843.88
# USD - ISM Non-Manufacturing PMI          : 🔮 Forecast for THIS month = 50487791.75
# USD - ISM Non-Manufacturing Prices Paid  : 🔮 Forecast for THIS month = 64678427.77
# USD - ISM-NY Business Conditions Index   : 🔮 Forecast for THIS month = 798559726.29
# USD - ISM-NY Current Business Conditions : 🔮 Forecast for THIS month = 42812132.05
# USD - Import Price Index excl. Petroleum : 🔮 Forecast for THIS month = 187296.53
# USD - Import Price Index m/m             : 🔮 Forecast for THIS month = -294383.23
# USD - Import Price Index y/y             : 🔮 Forecast for THIS month = -242193.50
# USD - Imports                            : 🔮 Forecast for THIS month = 374271748.89
# USD - Initial Jobless Claims             : 🔮 Forecast for THIS month = 224426883.82
# USD - Initial Jobless Claims 4-Week Avera: 🔮 Forecast for THIS month = 219345691.98
# USD - JOLTS Job Openings                 : 🔮 Forecast for THIS month = 7349434.74
# USD - Kansas City Fed Manufacturing Compo: 🔮 Forecast for THIS month = -4824737.67
# USD - Kansas City Fed Manufacturing Produ: 🔮 Forecast for THIS month = -7508312.46
# USD - MNI Chicago Business Barometer     : 🔮 Forecast for THIS month = 41672923.94
# USD - Manufacturing Payrolls             : 🔮 Forecast for THIS month = -57691358.92
# USD - Michigan 5-Year Inflation Expectati: 🔮 Forecast for THIS month = 4116696.55
# USD - Michigan Consumer Expectations     : 🔮 Forecast for THIS month = 52586613.00
# USD - Michigan Consumer Sentiment        : 🔮 Forecast for THIS month = 55976060.76
# USD - Michigan Current Conditions        : 🔮 Forecast for THIS month = 61143307.67
# USD - Michigan Inflation Expectations    : 🔮 Forecast for THIS month = 5649250.15
# USD - NAHB Housing Market Index          : 🔮 Forecast for THIS month = 34974396.23
# USD - NFIB Small Business Optimism       : 🔮 Forecast for THIS month = 97306548.25
# USD - NY Fed Empire State Manufacturing I: 🔮 Forecast for THIS month = -15549971.41
# USD - New Home Sales                     : 🔮 Forecast for THIS month = 692395.46
# USD - New Home Sales m/m                 : 🔮 Forecast for THIS month = 4097220.73
# USD - Nondefense Capital Goods Orders exc: 🔮 Forecast for THIS month = -787410.86
# USD - Nondefense Capital Goods Shipments : 🔮 Forecast for THIS month = -178756.60
# USD - Nonfarm Payrolls                   : 🔮 Forecast for THIS month = -770310580.73
# USD - Nonfarm Productivity q/q           : 🔮 Forecast for THIS month = -481650.02
# USD - PCE Price Index m/m                : 🔮 Forecast for THIS month = 73351.14
# USD - PCE Price Index q/q                : 🔮 Forecast for THIS month = 2792118.49
# USD - PCE Price Index y/y                : 🔮 Forecast for THIS month = 2113346.41
# USD - PPI m/m                            : 🔮 Forecast for THIS month = -58902.91
# USD - PPI y/y                            : 🔮 Forecast for THIS month = 2488473.09
# USD - Participation Rate                 : 🔮 Forecast for THIS month = 62379514.50
# USD - Pending Home Sales Index           : 🔮 Forecast for THIS month = 72919002.49
# USD - Pending Home Sales m/m             : 🔮 Forecast for THIS month = -2618288.97
# USD - Pending Home Sales y/y             : 🔮 Forecast for THIS month = -2919961.95
# USD - Personal Income m/m                : 🔮 Forecast for THIS month = 12553.94
# USD - Personal Spending m/m              : 🔮 Forecast for THIS month = -326227.95
# USD - Philadelphia Fed Business Condition: 🔮 Forecast for THIS month = 27969583.85
# USD - Philadelphia Fed Capex Index       : 🔮 Forecast for THIS month = 17031532.47
# USD - Philadelphia Fed Employment        : 🔮 Forecast for THIS month = 9340876.84
# USD - Philadelphia Fed Manufacturing Inde: 🔮 Forecast for THIS month = -8080230.31
# USD - Philadelphia Fed New Orders        : 🔮 Forecast for THIS month = -4057917.90
# USD - Philadelphia Fed Prices Paid       : 🔮 Forecast for THIS month = 48143981.93
# USD - Private Nonfarm Payrolls           : 🔮 Forecast for THIS month = -755714813.47
# USD - Real Earnings m/m                  : 🔮 Forecast for THIS month = 38220.03
# USD - Real PCE m/m                       : 🔮 Forecast for THIS month = -416152.67
# USD - Real PCE q/q                       : 🔮 Forecast for THIS month = 509653.38
# USD - Retail Control m/m                 : 🔮 Forecast for THIS month = -261906.28
# USD - Retail Inventories excl. Autos m/m : 🔮 Forecast for THIS month = 227767.63
# USD - Retail Inventories m/m             : 🔮 Forecast for THIS month = -381240.39
# USD - Retail Sales excl. Autos and Gas m/: 🔮 Forecast for THIS month = -456617.82
# USD - Retail Sales m/m                   : 🔮 Forecast for THIS month = -739733.43
# USD - Retail Sales y/y                   : 🔮 Forecast for THIS month = 2757294.13
# USD - Richmond Fed Manufacturing Index   : 🔮 Forecast for THIS month = -10248564.90
# USD - Richmond Fed Manufacturing Shipment: 🔮 Forecast for THIS month = -11888132.21
# USD - Richmond Fed Services Revenues     : 🔮 Forecast for THIS month = -6693297.15
# USD - S&P Global Composite PMI           : 🔮 Forecast for THIS month = 51436128.97
# USD - S&P Global Manufacturing PMI       : 🔮 Forecast for THIS month = 50338842.21
# USD - S&P Global Services PMI            : 🔮 Forecast for THIS month = 52326155.46
# USD - S&P/CS HPI Composite-20 n.s.a. m/m : 🔮 Forecast for THIS month = 152705.54
# USD - S&P/CS HPI Composite-20 s.a. m/m   : 🔮 Forecast for THIS month = 336644.83
# USD - S&P/CS HPI Composite-20 y/y        : 🔮 Forecast for THIS month = 3464936.38
# USD - TIC Net Foreign Purchases of Domest: 🔮 Forecast for THIS month = 62004267.50
# USD - TIC Net Long-Term Transactions     : 🔮 Forecast for THIS month = 123897111.94
# USD - TIC Net Long-Term Transactions incl: 🔮 Forecast for THIS month = 122300111.89
# USD - TIC Overall Net Capital Flow       : 🔮 Forecast for THIS month = 207730281.97
# USD - Trade Balance                      : 🔮 Forecast for THIS month = -98309727.33
# USD - U6 Unemployment Rate               : 🔮 Forecast for THIS month = 7697560.46
# USD - Unemployment Rate                  : 🔮 Forecast for THIS month = 4142474.93
# USD - Unit Labor Costs q/q               : 🔮 Forecast for THIS month = 4237212.54
# USD - Wholesale Inventories m/m          : 🔮 Forecast for THIS month = 84629.61
# USD - Wholesale Sales m/m                : 🔮 Forecast for THIS month = -173631.45
# ZAR - Absa Manufacturing PMI             : 🔮 Forecast for THIS month = 44842515.86
# ZAR - Building Permits m/m               : 🔮 Forecast for THIS month = -7250535.95
# ZAR - Building Permits y/y               : 🔮 Forecast for THIS month = 1081320.40
# ZAR - CFTC ZAR Non-Commercial Net Positio: 🔮 Forecast for THIS month = 9915770.21
# ZAR - CPI m/m                            : 🔮 Forecast for THIS month = 342483.19
# ZAR - CPI y/y                            : 🔮 Forecast for THIS month = 2803209.29
# ZAR - Consolidated Budget Balance        : 🔮 Forecast for THIS month = -360890925.60
# ZAR - Consolidated Budget Balance - GDP R: 🔮 Forecast for THIS month = -5449121.38
# ZAR - Core CPI m/m                       : 🔮 Forecast for THIS month = 164489.15
# ZAR - Core CPI y/y                       : 🔮 Forecast for THIS month = 3111085.13
# ZAR - Current Account                    : 🔮 Forecast for THIS month = -57214228.54
# ZAR - Current Account - GDP Ratio        : 🔮 Forecast for THIS month = -973594.61
# ZAR - FNB/BER Consumer Confidence Index  : 🔮 Forecast for THIS month = -14209392.55
# ZAR - GDP q/q                            : 🔮 Forecast for THIS month = -1594832.48
# ZAR - GDP y/y                            : 🔮 Forecast for THIS month = -41921.66
# ZAR - Gold Production y/y                : 🔮 Forecast for THIS month = -7797375.61
# ZAR - Gross International Reserves       : 🔮 Forecast for THIS month = 66382649.90
# ZAR - Manufacturing Production m/m       : 🔮 Forecast for THIS month = -1340475.54
# ZAR - Manufacturing Production y/y       : 🔮 Forecast for THIS month = -5511928.92
# ZAR - Mining Production m/m              : 🔮 Forecast for THIS month = -1144170.17
# ZAR - Mining Production y/y              : 🔮 Forecast for THIS month = -7180754.16
# ZAR - Net International Reserves         : 🔮 Forecast for THIS month = 62791103.80
# ZAR - PPI m/m                            : 🔮 Forecast for THIS month = 489758.40
# ZAR - PPI y/y                            : 🔮 Forecast for THIS month = 439740.68
# ZAR - RMB/BER Business Confidence Index  : 🔮 Forecast for THIS month = 40008653.40
# ZAR - Retail Sales m/m                   : 🔮 Forecast for THIS month = -118572.60
# ZAR - Retail Sales y/y                   : 🔮 Forecast for THIS month = 4003724.64
# ZAR - S&P Global PMI                     : 🔮 Forecast for THIS month = 49363411.78
# ZAR - SARB Interest Rate Decision        : 🔮 Forecast for THIS month = 7578569.80
# ZAR - SARB M3 Money Supply y/y           : 🔮 Forecast for THIS month = 6116849.05
# ZAR - SARB Prime Rate                    : 🔮 Forecast for THIS month = 11078569.80
# ZAR - SARB Private Sector Credit y/y     : 🔮 Forecast for THIS month = 3963775.82
# ZAR - Total New Vehicle Sales            : 🔮 Forecast for THIS month = 43719719.02
# ZAR - Total New Vehicle Sales m/m        : 🔮 Forecast for THIS month = -6838240.32
# ZAR - Total New Vehicle Sales y/y        : 🔮 Forecast for THIS month = 4070531.31
# ZAR - Trade Balance                      : 🔮 Forecast for THIS month = 15712568.55
# ZAR - Unemployment                       : 🔮 Forecast for THIS month = 7929045.93
# ZAR - Unemployment Rate                  : 🔮 Forecast for THIS month = 32111902.05
# ✅ Forecasts saved to: C:\Users\Nokul\Desktop\Codes\Python Codes\News Data\event_rnn_month_forecasts.csv
# ✅ Model weights saved to: C:\Users\Nokul\Desktop\Codes\Python Codes\News Data\event_rnn_model.pth
